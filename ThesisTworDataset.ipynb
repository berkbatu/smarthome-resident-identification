# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
twor_data=pd.read_csv("/Users/berkbatuhangurhan/Desktop/Tesi/TworDataset/twordata.csv",sep=';',index_col='date', parse_dates=['date'])
# Out:
# /Users/berkbatuhangurhan/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Analysis Part

# %%
#dataset=twor_data[['date','sensor','sensor_status']].head(20)
twor_data['label'].unique()
# Out:
# array([nan, 'R1_Wandering_in_room begin', 'R1_Wandering_in_room end',
#        'R1_Sleep begin', 'R1_Sleep end', 'R1_Wandering_in_room begin ',
#        'R2_Sleep begin ', 'R1_Bed_Toilet_Transition begin ',
#        'R1_Bed_Toilet_Transition end', 'R1_Personal_Hygiene begin',
#        'R1_Personal_Hygiene end', 'R1_Bathing begin ', 'R1_Bathing end',
#        'R1_Work begin', 'R1_Work end', 'R1_Meal_Preparation begin',
#        'R2_Sleep end', 'R2_Personal_Hygiene begin ',
#        'R1_Meal_Preparation end', 'R1_Leave_Home begin',
#        'R1_Leave_Home end', 'R2_Personal_Hygiene end', 'R2_Sleep begin',
#        'R2_Wandering_in_room begin', 'R2_Wandering_in_room end ',
#        'R2_Meal_Preparation begin', 'R2_Meal_Preparation end',
#        'R2_Eating begin', 'R2_Eating end', 'R2_Personal_Hygiene begin',
#        'R2_Work begin', 'R2_Work end', 'R2_Bathing begin',
#        'R2_Bathing end', 'R2_Leave_Home begin', 'R2_Leave_Home end',
# ...

# %%
twor_data[(twor_data['label']=='R1_Personal_Hygiene begin')|(twor_data['label']=='R1_Personal_Hygiene end')].head(50)
# Out:
#                              date sensor sensor_status  \
# 1211   2009-08-24 06:32:46.056996   D005         CLOSE
# 1265   2009-08-24 06:37:48.000383   M040           OFF
# 1298   2009-08-24 06:51:04.017432   M038           OFF
# 1327   2009-08-24 06:54:37.076348   D005          OPEN
# 1366   2009-08-24 06:55:56.043286   M038            ON
# 1432   2009-08-24 07:03:18.072023   M038           OFF
# 15914  2009-08-25 08:31:52.053654   M037            ON
# 15979  2009-08-25 08:33:11.003456   M037            ON
# 15998  2009-08-25 08:34:17.041403   M037            ON
# 24608  2009-08-25 23:03:19.001135   M037            ON
# 24709  2009-08-25 23:11:13.044307   M037            ON
# 24728  2009-08-25 23:12:22.071447   M037            ON
# 26320  2009-08-26 06:36:57.057166   M037            ON
# 26546  2009-08-26 07:01:57.006232   M037            ON
# 26595  2009-08-26 07:07:02.004455   M037            ON
# 35103  2009-08-26 23:06:51.013549   M039            ON
# ...

# %%
twor_data[['date','sensor','label']][(twor_data['label']=='R1_Sleep begin')|(twor_data['label']=='R1_Sleep end')].head(50)
# Out:
#                               date sensor           label
# 112     2009-08-24 00:04:38.039369   M047  R1_Sleep begin
# 131     2009-08-24 00:05:21.041611   M046    R1_Sleep end
# 208     2009-08-24 00:08:31.034365   M047  R1_Sleep begin
# 245     2009-08-24 00:10:14.017269   M048    R1_Sleep end
# 365     2009-08-24 00:15:47.003067   M047  R1_Sleep begin
# 381     2009-08-24 00:16:27.004872   M047    R1_Sleep end
# 547     2009-08-24 00:23:53.036405   M047  R1_Sleep begin
# 585     2009-08-24 00:27:08.075358   M049    R1_Sleep end
# 640     2009-08-24 00:29:27.062638   M046  R1_Sleep begin
# 724     2009-08-24 01:17:07.047033   M049    R1_Sleep end
# 969     2009-08-24 04:29:49.068014   M046  R1_Sleep begin
# 1210    2009-08-24 06:32:46.028358   P001    R1_Sleep end
# 13490   2009-08-24 23:46:35.093042   M046  R1_Sleep begin
# 14942   2009-08-25 07:38:41.087305   M049    R1_Sleep end
# 16055   2009-08-25 08:35:18.021273   M046  R1_Sleep begin
# ...

# %%
twor_data.count()
# Out:
# date             1048576
# sensor            948576
# sensor_status     948576
# label                690
# dtype: int64

# %%
ds=twor_data[twor_data['label']=='R1_Sleep begin']

# %%
plt.figure(figsize=(20,20))
plt.hist(twor_data[['date','sensor','label']][(twor_data['label']=='R1_Sleep begin')|(twor_data['label']=='R1_Sleep end')])
plt.show()

# %%
twor_data['label'].value_counts()
# Out:
# R1_Personal_Hygiene begin      54
# R1_Personal_Hygiene end        52
# R1_Work begin                  38
# R2_Personal_Hygiene end        34
# R2_Personal_Hygiene begin      34
#                                ..
# R2_Watch_TV end                 1
# R1_Meal_Preparation end         1
# R1_Bathing end                  1
# R2_Meal_Preparation begin       1
# R1_Wandering_in_room begin      1
# Name: label, Length: 68, dtype: int64
